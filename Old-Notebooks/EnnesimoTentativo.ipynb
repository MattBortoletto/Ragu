# %% [markdown]
# 0.0005196965286657252

# %%
import random
import numpy as np

def DNAgen(length):
    return ''.join(np.random.choice(["A", "T", "C", "G"], 
                                    p=[0.294474, 0.298237, 0.203473, 0.203816]) for _ in range(length))

#print(DNAgen(5))

# %% [markdown]
# Idea:
# - scelgo la lunghezza complessiva della sequenza di DNA
# - genero le parole importanti nel giusto numero
# - genero le restanti parole random in modo da arrivare al numero scelto inizialmente
# - faccio uno shuffle tenendo fisso il numero di parole

# %%
freq_imp = 0.0005196965286657252
len_dna = 10000000
imp_len = int(freq_imp*len_dna)
DNA_imp_intr = [None]*imp_len #51
DNA_imp_depl = [None]*imp_len

for i in range(imp_len):
    DNA_imp_intr[i] = np.random.choice(["CCGCG", "CGCGC", "GCGCC", "CGGCG", "CGGCC"], 
                                       p=[0.10554704, 0.11982444, 0.31040135, 0.10084078, 0.36338639])
    DNA_imp_depl[i] = np.random.choice(["CCGCG", "CGCGC", "GCGCC", "CGGCG", "CGGCC"], 
                                       p=[0.1158637, 0.12953683, 0.31133224, 0.09685733, 0.34640990])

# %%
DNA_imp_intr
# Out:
# ['GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCC',
#  'CCGCG',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'CCGCG',
#  'CGCGC',
#  'CGGCC',
#  'CGCGC',
#  'CCGCG',
#  'CGGCC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCG',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGCGC',
#  'CCGCG',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCG',
#  'GCGCC',
#  'CGGCG',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCG',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCG',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCG',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCG',
#  'CGCGC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCG',
#  'GCGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCG',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCG',
#  'CCGCG',
#  'CGGCG',
#  'CCGCG',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'CCGCG',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGCGC',
#  'CGCGC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGCGC',
#  'CGCGC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGCGC',
#  'CCGCG',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCG',
#  'CGCGC',
#  'CGGCG',
#  'CGCGC',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGCGC',
#  'CGGCG',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGCGC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCC',
#  'CCGCG',
#  'CGCGC',
#  'CCGCG',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCG',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGCGC',
#  'CCGCG',
#  'CCGCG',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CCGCG',
#  'CGCGC',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGCGC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGCGC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCG',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCG',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGCGC',
#  'GCGCC',
#  'CCGCG',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CCGCG',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CCGCG',
#  'CGCGC',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CCGCG',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCG',
#  'CCGCG',
#  'CGGCG',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGCGC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCG',
#  'CGGCG',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCG',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGCGC',
#  'GCGCC',
#  'CCGCG',
#  'CGCGC',
#  'CGGCC',
#  'CGGCG',
#  'CCGCG',
#  'CGGCC',
#  'CCGCG',
#  'CGGCG',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGCGC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CCGCG',
#  'GCGCC',
#  'CGCGC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGCGC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGCGC',
#  'CCGCG',
#  'CCGCG',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGCGC',
#  'GCGCC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CCGCG',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGCGC',
#  'CGGCG',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CCGCG',
#  'CGCGC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCG',
#  'CGGCC',
#  'CGCGC',
#  'CGCGC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCG',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCC',
#  'CCGCG',
#  'CGGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'CGGCC',
#  'CGCGC',
#  'CGGCC',
#  'CGGCG',
#  'CGGCC',
#  'GCGCC',
#  'GCGCC',
#  'GCGCC',
#  'CCGCG',
#  'GCGCC',
#  'CGCGC',
#  ...]

# %%
print(len(DNA_imp_intr), len(DNA_imp_depl))
# Out:
# 5196 5196

# %%
counter = 0
for n in range(len(DNA_imp_intr)):
    if DNA_imp_intr[n] == "CCGCG":
        counter += 1
        
print(counter)
# Out:
# 537

# %%
counter = 0
for n in range(len(DNA_imp_depl)):
    if DNA_imp_depl[n] == "CCGCG":
        counter += 1
        
print(counter)
# Out:
# 603

# %%
#len_dna = 500000
DNAc_intr = [None]*int(len_dna/5-len(DNA_imp_intr)) # DNA casuale
DNAc_depl = [None]*int(len_dna/5-len(DNA_imp_depl)) # DNA casuale
print(len(DNAc_intr))

words = ["CCGCG", "CGCGC", "GCGCC", "CGGCG", "CGGCC"]

for i in range(len(DNAc_intr)):
    DNAc_intr[i] = DNAgen(5)
    for w in words:
        while DNAc_intr[i] == w:
            DNAc_intr[i] = DNAgen(5)
    DNAc_depl[i] = DNAgen(5)
    for w in words:
        while DNAc_depl[i] == w:
            DNAc_depl[i] = DNAgen(5)
            
"""for i in range(len(DNAc_intr)):
    DNAc_intr[i] = DNAgen(5)
    if any(DNAc_intr[i] == words) == True:
        DNAc_intr[i] = DNAgen(5)
    DNAc_depl[i] = DNAgen(5)
    while any(DNAc_depl[i] == words) == True:
        DNAc_depl[i] = DNAgen(5)"""
# Out:
# 1994804
# 'for i in range(len(DNAc_intr)):\n    DNAc_intr[i] = DNAgen(5)\n    if any(DNAc_intr[i] == words) == True:\n        DNAc_intr[i] = DNAgen(5)\n    DNAc_depl[i] = DNAgen(5)\n    while any(DNAc_depl[i] == words) == True:\n        DNAc_depl[i] = DNAgen(5)'

# %%
print(len(DNAc_intr))
# Out:
# 1994804

# %%
#DNAc_depl[0:1000]

# %%
DNA_complete_intr = DNA_imp_intr + DNAc_intr
DNA_complete_depl = DNA_imp_depl + DNAc_depl
DNA_complete = DNA_complete_intr + DNA_complete_depl

print(len(DNA_complete_intr))
print(len(DNA_complete_depl))
print(len(DNA_complete))
# Out:
# 2000000
# 2000000
# 4000000

# %%
#DNA_complete

# %%
counter = 0
for n in range(len(DNA_complete)):
    if DNA_complete[n] == "CCGCG":
        counter += 1
        
print(counter)
# Out:
# 1142

# %%
sentence = 100

D = ""
j = 1
c = 0
DNA = [None]*int(len(DNA_complete)/sentence)

for i in DNA_complete:
    D = D + i + " "
    if j%100 == 0:
        DNA[c] = D
        D = ""
        c = c + 1
    j = j + 1

# %%
print(DNA[0:10])
# Out:
# ['GCGCC GCGCC CGCGC GCGCC CGGCG CGGCC CCGCG CGCGC GCGCC GCGCC CCGCG CGGCC CGGCC GCGCC CCGCG CGGCG GCGCC CGGCC CGGCG CGGCC CGGCC GCGCC CGGCC GCGCC CCGCG GCGCC CCGCG GCGCC CCGCG CGCGC CGGCC CGCGC CCGCG CGGCC CGCGC GCGCC CGGCC CCGCG CGGCC CGGCC GCGCC CCGCG CGGCG GCGCC CGCGC CGGCC GCGCC CGGCC CGGCC GCGCC GCGCC CGGCC CCGCG CGGCC GCGCC GCGCC CGGCG CGGCC GCGCC GCGCC CGGCC CGGCG CGGCC CGCGC CCGCG CGCGC CGGCC GCGCC GCGCC CGGCG CGGCG GCGCC CGGCG CCGCG CGGCC GCGCC GCGCC GCGCC CGGCC CGGCC CGGCC GCGCC CGGCC CGCGC CGGCG CGCGC CGGCC CGGCC CGGCC CGCGC GCGCC CGCGC CGGCG CGGCG GCGCC CGGCC CCGCG CCGCG CGGCC GCGCC ', 'CGGCC CGGCC CGGCC GCGCC CGGCC GCGCC CGGCC CCGCG CGGCG CGGCC CCGCG GCGCC CGGCG GCGCC CGGCG CGCGC CGGCC CGGCG CGGCG CGGCC GCGCC CGCGC CGCGC CGGCC CGGCG GCGCC GCGCC CGGCC CGGCC CGCGC CGGCG GCGCC CGCGC CGCGC CGGCC CCGCG CGGCC CGGCG GCGCC GCGCC CGGCG GCGCC CGGCC CGGCC GCGCC GCGCC CGGCC CGCGC CGCGC CGGCG GCGCC CGCGC CGGCC GCGCC CGCGC CGGCC GCGCC CGCGC CGCGC CGGCC GCGCC GCGCC CGGCC CGCGC GCGCC CGGCC CCGCG GCGCC GCGCC CGGCC CGGCC GCGCC CCGCG GCGCC GCGCC GCGCC GCGCC CGGCC GCGCC GCGCC CGGCC GCGCC GCGCC CGGCC CGGCC GCGCC CGGCG CGCGC CGGCC GCGCC CGGCC CGGCC CGGCC CGCGC CGCGC GCGCC CGGCC CGGCC GCGCC CGGCC ', 'CGGCC CGGCC CCGCG CGGCC GCGCC GCGCC CGCGC CGGCG CCGCG CGGCG CCGCG CGGCC CCGCG GCGCC GCGCC CGGCG CCGCG CGCGC GCGCC CGGCC CCGCG GCGCC GCGCC CGGCC GCGCC CGGCG CGGCC CGCGC CGCGC CCGCG CGGCC GCGCC CGGCG GCGCC CGGCC GCGCC GCGCC GCGCC GCGCC CGGCC CGGCC GCGCC CGGCC GCGCC CCGCG CCGCG CGGCC CGGCC CGGCC CGCGC CGGCC GCGCC CGGCC CGGCC GCGCC GCGCC GCGCC CCGCG GCGCC CGGCG CGGCC GCGCC CGGCC GCGCC CGGCC CGGCC CGGCG CGGCG CGGCC GCGCC CGGCC CCGCG CGCGC CGCGC CCGCG CGGCC GCGCC CGGCC CGGCC CGGCG CGGCC GCGCC CGGCC GCGCC CGCGC CCGCG CCGCG GCGCC GCGCC CGGCC GCGCC CGGCC CGGCC GCGCC GCGCC GCGCC CGCGC GCGCC GCGCC CGCGC ', 'GCGCC GCGCC CGGCC GCGCC GCGCC CCGCG GCGCC CGCGC GCGCC CGGCC CCGCG CGCGC CGGCC GCGCC CCGCG CGGCC CGGCC CGCGC CCGCG CGGCC CGGCC CGGCC CGGCC CGCGC CGGCC GCGCC CGGCC CGGCC CGGCC GCGCC CCGCG CGGCG CGCGC CGGCG CGCGC CGCGC GCGCC GCGCC CGGCC CGGCC CGGCC CGGCC GCGCC GCGCC CGGCC CCGCG GCGCC CCGCG CGGCC GCGCC CGGCC CGGCC CGGCC CGGCC CGGCC GCGCC CGGCG CGCGC CGGCG CGGCG GCGCC CGGCC CGGCC GCGCC CGCGC CGCGC CGGCC CGGCC CGGCC CGGCG CGGCC CGGCC CGGCG CGCGC CGCGC CGGCC GCGCC GCGCC GCGCC CGGCC GCGCC CGGCC CGGCC GCGCC GCGCC CGCGC CGGCG GCGCC CGGCC CGCGC CGGCC CCGCG GCGCC CGGCC CGGCC CGGCG GCGCC GCGCC CGGCC CGGCG ', 'CGGCC GCGCC CGGCC GCGCC GCGCC CGCGC CGCGC CGCGC CGGCC CCGCG CGCGC CCGCG CCGCG GCGCC CGGCC CGGCG CGGCG GCGCC GCGCC GCGCC CGCGC GCGCC CGGCC CGCGC CGGCC CGCGC CGGCG GCGCC CGGCC GCGCC GCGCC CGCGC GCGCC CGGCC GCGCC CGGCC CGGCC CGGCC CGCGC CGGCC CCGCG CGGCG CGGCC CGGCG GCGCC GCGCC CGGCG GCGCC CGCGC CGGCC CGGCC GCGCC GCGCC CGGCC GCGCC CGGCC CGGCC GCGCC CCGCG CGCGC CCGCG CCGCG GCGCC CCGCG CGGCC CGGCC GCGCC CGGCC GCGCC CGGCC CGCGC CCGCG CGCGC CCGCG GCGCC GCGCC CCGCG CGGCC CCGCG CGGCC CGCGC GCGCC GCGCC GCGCC GCGCC GCGCC GCGCC CGGCC CGGCC CGGCC CGGCC CGGCC CGGCC CGGCC CGGCG GCGCC GCGCC CGGCC GCGCC CGGCG ', 'GCGCC CCGCG CGGCC CGCGC CCGCG CGGCC CGGCG CGGCC CGGCC CGGCC CGGCC CGGCC CGCGC CGCGC CCGCG GCGCC CGGCC GCGCC CGGCC CGGCC GCGCC CGGCC CGGCC CGGCC CGCGC GCGCC GCGCC GCGCC CGCGC CGGCG GCGCC CGGCC CCGCG GCGCC CGGCC CGGCG CGGCC CGGCG CCGCG CGGCC GCGCC CGGCC GCGCC CCGCG CGGCC GCGCC CGGCC CGGCC CGGCG GCGCC GCGCC CGGCC CGGCG GCGCC CGGCG CCGCG GCGCC CGGCC CGGCC CCGCG CGCGC GCGCC CCGCG CGCGC CGGCC CGGCC GCGCC GCGCC CGGCC GCGCC GCGCC GCGCC CGCGC GCGCC CCGCG CGGCC CGCGC CGGCC CGGCC CGCGC CGGCC CCGCG CGCGC CGGCC CGGCC CGCGC CGGCG CGGCC CGGCC CGCGC CGGCC GCGCC GCGCC GCGCC CGGCC GCGCC CGGCC CGGCC CGGCC CGGCC ', 'GCGCC CGGCC CGGCC CGGCC CGCGC CGGCC CGCGC CGCGC CGGCC GCGCC CGGCC CGGCC CGGCG CGGCC CCGCG CGGCC CGCGC CGGCC GCGCC CGGCG GCGCC CGGCC CGCGC CGGCC CCGCG CGGCC GCGCC CGGCC GCGCC CCGCG CGGCC CGGCC CGGCC CGGCG CGGCC CGCGC CGGCC CGGCG CGGCC CGGCG GCGCC GCGCC CCGCG CGGCG CGGCC GCGCC CCGCG CCGCG CGCGC CCGCG GCGCC GCGCC CGGCC CCGCG CCGCG CGCGC CGGCC CGGCC CGGCC CCGCG GCGCC CGCGC CG ...

# %%
labels = list(np.ones(int(len(DNA)/2))) + list(np.zeros(int(len(DNA)/2)))

# %%
print(len(labels))
#print(labels[0:10], labels[int(len(DNA)/2)-1:])
# Out:
# 40000

# %% [markdown]
# # LSTM

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD, Adam, Adadelta, RMSprop
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Flatten, Dropout
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, LSTM, SimpleRNN, GRU

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools

from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, LSTM, SimpleRNN, GRU, Bidirectional

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(DNA)
#X = tokenizer.texts_to_matrix(merge_texts, mode = 'freq')

encoded_docs = tokenizer.texts_to_sequences(DNA)
max_length = max([len(s.split()) for s in DNA])
X = pad_sequences(encoded_docs, maxlen = max_length, padding = 'post')

print(X)
print('\n')
print(X.shape)
# Out:
# [[ 514  514 1022 ... 1023  513  514]
#  [ 513  513  513 ...  513  514  513]
#  [ 513  513 1023 ...  514  514 1022]
#  ...
#  [ 580   59  216 ...   14   83 1003]
#  [ 455  172  959 ...  978   95  270]
#  [ 327   92   76 ...  457  147    4]]
#
#
# (40000, 100)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size = 0.20, random_state = 42)

# %%
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(type(X_train))
print(type(X_test))
print(type(y_train))
print(type(y_test))
# Out:
# (32000, 100)
# (8000, 100)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
max_length = max([len(s.split()) for s in DNA])
print(max_length)

vocab_size = len(tokenizer.word_index) + 1
print(vocab_size)
# Out:
# 100
# 1025

# %%
model = Sequential()
model.add(Embedding(vocab_size, 10)) #dropout = 0.2 #input_length = max_length
#model.add(Conv1D(filters = 16, kernel_size = 5, padding = 'same', activation = 'relu'))
#model.add(MaxPooling1D(pool_size = 2))
#model.add(LSTM(10)) #dropout = 0.2, recurrent_dropout = 0.2
model.add(Bidirectional(LSTM(10))) #dropout = 0.2, recurrent_dropout = 0.2
#model.add(Bidirectional(SimpleRNN(10)))
#model.add(GRU(10))
#model.add(SimpleRNN(10, dropout = 0.2, recurrent_dropout = 0.2))
#model.add(Flatten())
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

epochs = 5
model.compile(loss = 'binary_crossentropy', optimizer = 'rmsprop', metrics = ['accuracy'])
#model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
#model.compile(loss = 'binary_crossentropy', optimizer = 'SGD', metrics = ['accuracy'])
#model.compile(loss = 'binary_crossentropy', optimizer = RMSprop(lr = 0.0001), metrics = ['accuracy'])
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor = 'val_acc', verbose = 1, 
                             save_best_only = True, mode = 'max')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 10)          10250
# _________________________________________________________________
# bidirectional (Bidirectional (None, 20)                1680
# _________________________________________________________________
# dense (Dense)                (None, 10)                210
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 12,151
# Trainable params: 12,151
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(X_train, y_train, 
                    epochs = epochs, verbose = 1, validation_split = 0.2, batch_size = 32, shuffle = True, 
                    callbacks = [checkpoint])
# Out:
# Train on 25600 samples, validate on 6400 samples
# Epoch 1/5
# 25536/25600 [============================>.] - ETA: 0s - loss: 0.6933 - accuracy: 0.4997WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 25600/25600 [==============================] - 29s 1ms/sample - loss: 0.6933 - accuracy: 0.4995 - val_loss: 0.6932 - val_accuracy: 0.4955
# Epoch 2/5
# 25504/25600 [============================>.] - ETA: 0s - loss: 0.6895 - accuracy: 0.5392WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 25600/25600 [==============================] - 21s 819us/sample - loss: 0.6895 - accuracy: 0.5392 - val_loss: 0.6961 - val_accuracy: 0.5027
# Epoch 3/5
# 25504/25600 [============================>.] - ETA: 0s - loss: 0.6766 - accuracy: 0.5756WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 25600/25600 [==============================] - 21s 815us/sample - loss: 0.6768 - accuracy: 0.5750 - val_loss: 0.7086 - val_accuracy: 0.4997
# Epoch 4/5
# 25536/25600 [============================>.] - ETA: 0s - loss: 0.6638 - accuracy: 0.5992WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 25600/25600 [==============================] - 18s 695us/sample - loss: 0.6638 - accuracy: 0.5991 - val_loss: 0.7143 - val_accuracy: 0.4980
# Epoch 5/5
# 25568/25600 [============================>.] - ETA: 0s - loss: 0.6522 - accuracy: 0.6201WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 25600/25600 [==============================] - 19s 737us/sample - loss: 0.6522 - accuracy: 0.6201 - val_loss: 0.7297 - val_accuracy: 0.4972

# %%
plt.figure(figsize = (15,10))

predicted_labels = model.predict(X_test)
cm = confusion_matrix(y_test, [np.round(i[0]) for i in predicted_labels])
print('Confusion matrix:\n',cm)

cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]

plt.imshow(cm, cmap = plt.cm.Blues)
plt.title('Normalized confusion matrix', fontsize = 20)
plt.colorbar()
plt.xlabel('True label', fontsize = 20)
plt.ylabel('Predicted label', fontsize = 20)
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], '.2f'),
             horizontalalignment = 'center', verticalalignment = 'center', fontsize = 20,
             color='white' if cm[i, j] > 0.5 else 'black')
plt.show()
# Out:
# Confusion matrix:
#  [[1516 2470]
#  [1493 2521]]

# %%
scores = model.evaluate(X_test, y_test, verbose = 0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 50.46%
