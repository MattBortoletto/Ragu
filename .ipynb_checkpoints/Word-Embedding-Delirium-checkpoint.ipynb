# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import subprocess
import numpy as np
from Bio import SeqIO

import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import SGD, Adam, Adadelta, RMSprop
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Flatten, Dropout
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, LSTM, SimpleRNN, GRU

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools

# %%
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Flatten, Dropout
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, LSTM, SimpleRNN, GRU, Bidirectional

model = Sequential()
model.add(Embedding(944238, 10))
model.add(Bidirectional(LSTM(10)))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

model.load_weights("LSTM.weights.best.hdf5")
model.compile(loss = 'binary_crossentropy', optimizer = 'rmsprop', metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 10)          9442380
# _________________________________________________________________
# bidirectional (Bidirectional (None, 20)                1680
# _________________________________________________________________
# dense (Dense)                (None, 10)                210
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 9,444,281
# Trainable params: 9,444,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
map_model = model.layers[0].get_weights()[0]
map_model.shape
# Out:
# (944238, 10)

# %%
W = np.dot(map_model.T, map_model)
W.shape

L, V = np.linalg.eig(W)
print("autovalori: \n", L/sum(L), "\nAutovettori: \n", V )
# Out:
# autovalori:
#  [0.45052958 0.20452735 0.13294284 0.05297361 0.03502827 0.02820135
#  0.02563945 0.0248255  0.02244739 0.02288468]
# Autovettori:
#  [[-0.3565962   0.28863195  0.16868278 -0.3830345  -0.2288914  -0.56555456
#    0.39091864  0.29508433  0.04180137  0.02187973]
#  [ 0.3472277  -0.2164808   0.21847095 -0.17354335 -0.1870409   0.02888667
#    0.0511008  -0.00897646  0.81153387  0.24005063]
#  [ 0.2705584   0.36315823  0.01225784 -0.68503886 -0.01814045  0.39778107
#    0.13738233 -0.3259438  -0.16259931 -0.12399632]
#  [ 0.28874233  0.52774245  0.14629456  0.43801522 -0.18244396  0.05115189
#    0.10521481  0.14981087  0.1898522  -0.56515193]
#  [-0.33469695  0.21112575 -0.28032807 -0.00548528  0.49841222  0.43750834
#    0.257219    0.37256798  0.3352212   0.08729205]
#  [ 0.26754054  0.05919605 -0.5552351  -0.3028749   0.03831415 -0.27683127
#   -0.5143017   0.37039328  0.09706153 -0.18888308]
#  [ 0.2972347  -0.18708314  0.40345165 -0.11324511  0.7323453  -0.2856631
#    0.10532651  0.0730483  -0.06267238 -0.25052574]
#  [ 0.34950608 -0.07065876 -0.57009876  0.16814788  0.04505185 -0.2609043
#    0.61500067 -0.24720024 -0.02923792  0.09631815]
#  [-0.28324312 -0.54823357 -0.13052417 -0.16788858 -0.17485419  0.13352571
#    0.18807791 -0.04425228  0.12039536 -0.6883026 ]
#  [-0.3483798   0.26608384 -0.10282047  0.03136323  0.24534377 -0.28794897
#   -0.24344733 -0.66314524  0.36893237 -0.13426724]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
map_model = scaler.fit_transform(map_model)

# %%
map_model.shape
# Out:
# (944238, 10)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
emb_pca = pca.fit_transform(map_model)
emb_pca.shape
# Out:
# (944238, 2)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0, perplexity = 30, verbose=2)
emb_tsne = tsne.fit_transform(emb_pca)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 944238 samples in 0.871s...
# [t-SNE] Computed neighbors for 944238 samples in 24.952s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 944238
# [t-SNE] Computed conditional probabilities for sample 2000 / 944238
# [t-SNE] Computed conditional probabilities for sample 3000 / 944238
# [t-SNE] Computed conditional probabilities for sample 4000 / 944238
# [t-SNE] Computed conditional probabilities for sample 5000 / 944238
# [t-SNE] Computed conditional probabilities for sample 6000 / 944238
# [t-SNE] Computed conditional probabilities for sample 7000 / 944238
# [t-SNE] Computed conditional probabilities for sample 8000 / 944238
# [t-SNE] Computed conditional probabilities for sample 9000 / 944238
# [t-SNE] Computed conditional probabilities for sample 10000 / 944238
# [t-SNE] Computed conditional probabilities for sample 11000 / 944238
# [t-SNE] Computed conditional probabilities for sample 12000 / 944238
# [t-SNE] Computed conditional probabilities for sample 13000 / 944238
# [t-SNE] Computed conditional probabilities for sample 14000 / 944238
# [t-SNE] Computed conditional probabilities for sample 15000 / 944238
# [t-SNE] Computed conditional probabilities for sample 16000 / 944238
# [t-SNE] Computed conditional probabilities for sample 17000 / 944238
# [t-SNE] Computed conditional probabilities for sample 18000 / 944238
# [t-SNE] Computed conditional probabilities for sample 19000 / 944238
# [t-SNE] Computed conditional probabilities for sample 20000 / 944238
# [t-SNE] Computed conditional probabilities for sample 21000 / 944238
# [t-SNE] Computed conditional probabilities for sample 22000 / 944238
# [t-SNE] Computed conditional probabilities for sample 23000 / 944238
# [t-SNE] Computed conditional probabilities for sample 24000 / 944238
# [t-SNE] Computed conditional probabilities for sample 25000 / 944238
# [t-SNE] Computed conditional probabilities for sample 26000 / 944238
# [t-SNE] Computed conditional probabilities for sample 27000 / 944238
# [t-SNE] Computed conditional probabilities for sample 28000 / 944238
# [t-SNE] Computed conditional probabilities for sample 29000 / 944238
# [t-SNE] Computed conditional probabilities for sample 30000 / 944238
# [t-SNE] Computed conditional probabilities for sample 31000 / 944238
# [t-SNE] Computed conditional probabilities for sample 32000 / 944238
# [t-SNE] Computed conditional probabilities for sample 33000 / 944238
# [t-SNE] Computed conditional probabilities for sample 34000 / 944238
# [t-SNE] Computed conditional probabilities for sample 35000 / 944238
# [t-SNE] Computed conditional probabilities for sample 36000 / 944238
# [t-SNE] Computed conditional probabilities for sample 37000 / 944238
# [t-SNE] Computed conditional probabilities for sample 38000 / 944238
# [t-SNE] Computed conditional probabilities for sample 39000 / 944238
# [t-SNE] Computed conditional probabilities for sample 40000 / 944238
# [t-SNE] Computed conditional probabilities for sample 41000 / 944238
# [t-SNE] Computed conditional probabilities for sample 42000 / 944238
# [t-SNE] Computed conditional probabilities for sample 43000 / 944238
# [t-SNE] Computed conditional probabilities for sample 44000 / 944238
# [t-SNE] Computed conditional probabilities for sample 45000 / 944238
# [t-SNE] Computed conditional probabilities for sample 46000 / 944238
# [t-SNE] Computed conditional probabilities for sample 47000 / 944238
# [t-SNE] Computed conditional probabilities for sample 48000 / 944238
# [t-SNE] Computed conditional probabilities for sample 49000 / 944238
# [t-SNE] Computed conditional probabilities for sample 50000 / 944238
# [t-SNE] Computed conditional probabilities for sample 51000 / 944238
# [t-SNE] Computed conditional probabilities for sample 52000 / 944238
# [t-SNE] Computed conditional probabilities for sample 53000 / 944238
# [t-SNE] Computed conditional probabilities for sample 54000 / 944238
# [t-SNE] Computed conditional probabilities for sample 55000 / 944238
# [t-SNE] Computed conditional probabilities for sample 56000 / 944238
# [t-SNE] Computed conditional probabilities for sample 57000 / 944238
# [t-SNE] Computed conditional probabilities for sample 58000 / 944238
# [t-SNE] Computed conditional probabilities for sample 59000 / 944238
# [t-SNE] Computed conditional probabilities for sample 60000 / 944238
# [t-SNE] Computed conditional probabilities for sample 61000 / 944238
# [t-SNE] Computed conditional probabilities for sample 62000 / 944238
# [t-SNE] Computed conditional probabilities for sample 63000 / 944238
# [t-SNE] Computed conditional probabilities for sample 64000 / 944238
# [t-SNE] Computed conditional probabilities for sample 65000 / 944238
# [t-SNE] Computed conditional probabilities for sample 66000 / 944238
# [t-SNE] Computed conditional probabilities for sample 67000 / 944238
# [t-SNE] Computed conditional probabilities for sample 68000 / 944238
# [t-SNE] Computed conditional probabilities for sample 69000 / 944238
# [t-SNE] Computed conditional probabilities for sample 70000 / 944238
# [t-SNE] Computed conditional probabilities for sample 71000 / 944238
# [t-SNE] Computed conditional probabilities for sample 72000 / 944238
# [t-SNE] Computed conditional probabilities for sample 73000 / 944238
# [t-SNE] Computed conditional probabilities for sample 74000 / 944238
# [t-SNE] Computed conditional probabilities for sample 75000 / 944238
# [t-SNE] Computed conditional probabilities for sample 76000 / 944238
# [t-SNE] Computed conditional probabilities for sample 77000 / 944238
# [t-SNE] Computed conditional probabilities for sample 78000 / 944238
# [t-SNE] Computed conditional probabilities for sample 79000 / 944238
# [t-SNE] Computed conditional probabilities for sample 80000 / 944238
# [t-SNE] Computed conditional probabilities for sample 81000 / 944238
# [t-SNE] Computed conditional probabilities for sample 82000 / 944238
# [t-SNE] Computed conditional probabilities for sample 83000 / 944238
# [t-SNE] Computed conditional probabilities for sample 84000 / 944238
# [t-SNE] Computed conditional probabilities for sample 85000 / 944238
# [t-SNE] Computed conditional probabilities for sample 86000 / 944238
# [t-SNE] Computed conditional probabilities for sample 87000 / 944238
# [t-SNE] Computed conditional probabilities for sample 88000 / 944238
# [t-SNE] Computed conditional probabilities for sample 89000 / 944238
# [t-SNE] Computed conditional probabilities for sample 90000 / 944238
# [t-SNE] Computed conditional probabilities for sample 91000 / 944238
# [t-SNE] Computed conditional probabilities for sample 92000 / 944238
# [t-SNE] Computed conditional probabilities for sample 93000 / 944238
# [t-SNE] Computed conditional probabilities for sample 94000 / 944238
# [t-SNE] Computed conditional probabilities for sample 95000 / 944238
# [t-SNE] Computed conditional probabilities for sample 96000 / 944238
# [t-SNE] Computed conditional probabilities for sample 97000 / 944238
# [t-SNE] Computed conditional probabilities for sample 98000 / 944238
# [t-SNE] Computed conditional probabilities for sample 99000 / 944238
# [t-SNE] Computed conditional probabilities for sample 100000 / 944238
# [t-SNE] Computed conditional probabilities for sample 101000 / 944238
# [t-SNE] Computed conditional probabilities for sample 102000 / 944238
# [t-SNE] Computed conditional probabilities for sample 103000 / 944238
# [t-SNE] Computed conditional probabilities for sample 104000 / 944238
# [t-SNE] Computed conditional probabilities for sample 105000 / 944238
# [t-SNE] Computed conditional probabilities for sample 106000 / 944238
# [t-SNE] Computed conditional probabilities for sample 107000 / 944238
# [t-SNE] Computed conditional probabilities for sample 108000 / 944238
# [t-SNE] Computed conditional probabilities for sample 109000 / 944238
# [t-SNE] Computed conditional probabilities for sample 110000 / 944238
# [t-SNE] Computed conditional probabilities for sample 111000 / 944238
# [t-SNE] Computed conditional probabilities for sample 112000 / 944238
# [t-SNE] Computed conditional probabilities for sample 113000 / 944238
# [t-SNE] Computed conditional probabilities for sample 114000 / 944238
# [t-SNE] Computed conditional probabilities for sample 115000 / 944238
# [t-SNE] Computed conditional probabilities for sample 116000 / 944238
# [t-SNE] Computed conditional probabilities for sample 117000 / 944238
# [t-SNE] Computed conditional probabilities for sample 118000 / 944238
# [t-SNE] Computed conditional probabilities for sample 119000 / 944238
# [t-SNE] Computed conditional probabilities for sample 120000 / 944238
# [t-SNE] Computed conditional probabilities for sample 121000 / 944238
# [t-SNE] Computed conditional probabilities for sample 122000 / 944238
# [t-SNE] Computed conditional probabilities for sample 123000 / 944238
# [t-SNE] Computed conditional probabilities for sample 124000 / 944238
# [t-SNE] Computed conditional probabilities for sample 125000 / 944238
# [t-SNE] Computed conditional probabilities for sample 126000 / 944238
# [t-SNE] Computed conditional probabilities for sample 127000 / 944238
# [t-SNE] Computed conditional probabilities for sample 128000 / 944238
# [t-SNE] Computed conditional probabilities for sample 129000 / 944238
# [t-SNE] Computed conditional probabilities for sample 130000 / 944238
# [t-SNE] Computed conditional probabilities for sample 131000 / 944238
# [t-SNE] Computed conditional probabilities for sample 132000 / 944238
# [t-SNE] Computed conditional probabilities for sample 133000 / 944238
# [t-SNE] Computed conditional probabilities for sample 134000 / 944238
# [t-SNE] Computed conditional probabilities for sample 135000 / 944238
# [t-SNE] Computed conditional probabilities for sample 136000 / 944238
# [t-SNE] Computed conditional probabilities for sample 137000 / 944238
# [t-SNE] Computed conditional probabilities for sample 138000 / 944238
# [t-SNE] Computed conditional probabilities for sample 139000 / 944238
# [t-SNE] Computed conditional probabilities for sample 140000 / 944238
# [t-SNE] Computed conditional probabilities for sample 141000 / 944238
# [t-SNE] Computed conditional probabilities for sample 142000 / 944238
# [t-SNE] Computed conditional probabilities for sample 143000 / 944238
# [t-SNE] Computed conditional probabilities for sample 144000 / 944238
# [t-SNE] Computed conditional probabilities for sample 145000 / 944238
# [t-SNE] Computed conditional probabilities for sample 146000 / 944238
# [t-SNE] Computed conditional probabilities for sample 147000 / 944238
# [t-SNE] Computed conditional probabilities for sample 148000 / 944238
# [t-SNE] Computed conditional probabilities for sample 149000 / 944238
# [t-SNE] Computed conditional probabilities for sample 150000 / 944238
# [t-SNE] Computed conditional probabilities for sample 151000 / 944238
# [t-SNE] Computed conditional probabilities for sample 152000 / 944238
# [t-SNE] Computed conditional probabilities for sample 153000 / 944238
# [t-SNE] Computed conditional probabilities for sample 154000 / 944238
# [t-SNE] Computed conditional probabilities for sample 155000 / 944238
# [t-SNE] Computed conditional probabilities for sample 156000 / 944238
# [t-SNE] Computed conditional probabilities for sample 157000 / 944238
# [t-SNE] Computed conditional probabilities for sample 158000 / 944238
# [t-SNE] Computed conditional probabilities for sample 159000 / 944238
# [t-SNE] Computed conditional probabilities for sample 160000 / 944238
# [t-SNE] Computed conditional probabilities for sample 161000 / 944238
# [t-SNE] Computed conditional probabilities for sample 162000 / 944238
# [t-SNE] Computed conditional probabilities for sample 163000 / 944238
# [t-SNE] Computed conditional probabilities for sample 164000 / 944238
# [t-SNE] Computed conditional probabilities for sample 165000 / 944238
# [t-SNE] Computed conditional probabilities for sample 166000 / 944238
# [t-SNE] Computed conditional probabilities for sample 167000 / 944238
# [t-SNE] Computed conditional probabilities for sample 168000 / 944238
# [t-SNE] Computed conditional probabilities for sample 169000 / 944238
# [t-SNE] Computed conditional probabilities for sample 170000 / 944238
# [t-SNE] Computed conditional probabilities for sample 171000 / 944238
# [t-SNE] Computed conditional probabilities for sample 172000 / 944238
# [t-SNE] Computed conditional probabilities for sample 173000 / 944238
# [t-SNE] Computed conditional probabilities for sample 174000 / 944238
# [t-SNE] Computed conditional probabilities for sample 175000 / 944238
# [t-SNE] Computed conditional probabilities for sample 176000 / 944238
# [t-SNE] Computed conditional probabilities for sample 177000 / 944238
# [t-SNE] Computed conditional probabilities for sample 178000 / 944238
# [t-SNE] Computed conditional probabilities for sample 179000 / 944238
# [t-SNE] Computed conditional probabilities for sample 180000 / 944238
# [t-SNE] Computed conditional probabilities for sample 181000 / 944238
# [t-SNE] Computed conditional probabilities for sample 182000 / 944238
# [t-SNE] Computed conditional probabilities for sample 183000 / 944238
# [t-SNE] Computed conditional probabilities for sample 184000 / 944238
# [t-SNE] Computed conditional probabilities for sample 185000 / 944238
# [t-SNE] Computed conditional probabilities for sample 186000 / 944238
# [t-SNE] Computed conditional probabilities for sample 187000 / 944238
# [t-SNE] Computed conditional probabilities for sample 188000 / 944238
# [t-SNE] Computed conditional probabilities for sample 189000 / 944238
# [t-SNE] Computed conditional probabilities for sample 190000 / 944238
# [t-SNE] Computed conditional probabilities for sample 191000 / 944238
# [t-SNE] Computed conditional probabilities for sample 192000 / 944238
# [t-SNE] Computed conditional probabilities for sample 193000 / 944238
# [t-SNE] Computed conditional probabilities for sample 194000 / 944238
# [t-SNE] Computed conditional probabilities for sample 195000 / 944238
# [t-SNE] Computed conditional probabilities for sample 196000 / 944238
# [t-SNE] Computed conditional probabilities for sample 197000 / 944238
# [t-SNE] Computed conditional probabilities for sample 198000 / 944238
# [t-SNE] Computed conditional probabilities for sample 199000 / 944238
# [t-SNE] Computed conditional probabilities for sample 200000 / 944238
# [t-SNE] Computed conditional probabilities for sample 201000 / 944238
# [t-SNE] Computed conditional probabilities for sample 202000 / 944238
# [t-SNE] Computed conditional probabilities for sample 203000 / 944238
# [t-SNE] Computed conditional probabilities for sample 204000 / 944238
# [t-SNE] Computed conditional probabilities for sample 205000 / 944238
# [t-SNE] Computed conditional probabilities for sample 206000 / 944238
# [t-SNE] Computed conditional probabilities for sample 207000 / 944238
# [t-SNE] Computed conditional probabilities for sample 208000 / 944238
# [t-SNE] Computed conditional probabilities for sample 209000 / 944238
# [t-SNE] Computed conditional probabilities for sample 210000 / 944238
# [t-SNE] Computed conditional probabilities for sample 211000 / 944238
# [t-SNE] Computed conditional probabilities for sample 212000 / 944238
# [t-SNE] Computed conditional probabilities for sample 213000 / 944238
# [t-SNE] Computed conditional probabilities for sample 214000 / 944238
# [t-SNE] Computed conditional probabilities for sample 215000 / 944238
# [t-SNE] Computed conditional probabilities for sample 216000 / 944238
# [t-SNE] Computed conditional probabilities for sample 217000 / 944238
# [t-SNE] Computed conditional probabilities for sample 218000 / 944238
# [t-SNE] Computed conditional probabilities for sample 219000 / 944238
# [t-SNE] Computed conditional probabilities for sample 220000 / 944238
# [t-SNE] Computed conditional probabilities for sample 221000 / 944238
# [t-SNE] Computed conditional probabilities for sample 222000 / 944238
# [t-SNE] Computed conditional probabilities for sample 223000 / 944238
# [t-SNE] Computed conditional probabilities for sample 224000 / 944238
# [t-SNE] Computed conditional probabilities for sample 225000 / 944238
# [t-SNE] Computed conditional probabilities for sample 226000 / 944238
# [t-SNE] Computed conditional probabilities for sample 227000 / 944238
# [t-SNE] Computed conditional probabilities for sample 228000 / 944238
# [t-SNE] Computed conditional probabilities for sample 229000 / 944238
# [t-SNE] Computed conditional probabilities for sample 230000 / 944238
# [t-SNE] Computed conditional probabilities for sample 231000 / 944238
# [t-SNE] Computed conditional probabilities for sample 232000 / 944238
# [t-SNE] Computed conditional probabilities for sample 233000 / 944238
# [t-SNE] Computed conditional probabilities for sample 234000 / 944238
# [t-SNE] Computed conditional probabilities for sample 235000 / 944238
# [t-SNE] Computed conditional probabilities for sample 236000 / 944238
# [t-SNE] Computed conditional probabilities for sample 237000 / 944238
# [t-SNE] Computed conditional probabilities for sample 238000 / 944238
# [t-SNE] Computed conditional probabilities for sample 239000 / 944238
# [t-SNE] Computed conditional probabilities for sample 240000 / 944238
# [t-SNE] Computed conditional probabilities for sample 241000 / 944238
# [t-SNE] Computed conditional probabilities for sample 242000 / 944238
# [t-SNE] Computed conditional probabilities for sample 243000 / 944238
# [t-SNE] Computed conditional probabilities for sample 244000 / 944238
# [t-SNE] Computed conditional probabilities for sample 245000 / 944238
# [t-SNE] Computed conditional probabilities for sample 246000 / 944238
# [t-SNE] Computed conditional probabilities for sample 247000 / 944238
# [t-SNE] Computed conditional probabilities for sample 248000 / 944238
# [t-SNE] Computed conditional probabilities for sample 249000 / 944238
# [t-SNE] Computed conditional probabilities for sample 250000 / 944238
# [t-SNE] Computed conditional probabilities for sample 251000 / 944238
# [t-SNE] Computed conditional probabilities for sample 252000 / 944238
# [t-SNE] Computed conditional probabilities for sample 253000 / 944238
# [t-SNE] Computed conditional probabilities for sample 254000 / 944238
# [t-SNE] Computed conditional probabilities for sample 255000 / 944238
# [t-SNE] Computed conditional probabilities for sample 256000 / 944238
# [t-SNE] Computed conditional probabilities for sample 257000 / 944238
# [t-SNE] Computed conditional probabilities for sample 258000 / 944238
# [t-SNE] Computed conditional probabilities for sample 259000 / 944238
# [t-SNE] Computed conditional probabilities for sample 260000 / 944238
# [t-SNE] Computed conditional probabilities for sample 261000 / 944238
# [t-SNE] Computed conditional probabilities for sample 262000 / 944238
# [t-SNE] Computed conditional probabilities for sample 263000 / 944238
# [t-SNE] Computed conditional probabilities for sample 264000 / 944238
# [t-SNE] Computed conditional probabilities for sample 265000 / 944238
# [t-SNE] Computed conditional probabilities for sample 266000 / 944238
# [t-SNE] Computed conditional probabilities for sample 267000 / 944238
# [t-SNE] Computed conditional probabilities for sample 268000 / 944238
# [t-SNE] Computed conditional probabilities for sample 269000 / 944238
# [t-SNE] Computed conditional probabilities for sample 270000 / 944238
# [t-SNE] Computed conditional probabilities for sample 271000 / 944238
# [t-SNE] Computed conditional probabilities for sample 272000 / 944238
# [t-SNE] Computed conditional probabilities for sample 273000 / 944238
# [t-SNE] Computed conditional probabilities for sample 274000 / 944238
# [t-SNE] Computed conditional probabilities for sample 275000 / 944238
# [t-SNE] Computed conditional probabilities for sample 276000 / 944238
# [t-SNE] Computed conditional probabilities for sample 277000 / 944238
# [t-SNE] Computed conditional probabilities for sample 278000 / 944238
# [t-SNE] Computed conditional probabilities for sample 279000 / 944238
# [t-SNE] Computed conditional probabilities for sample 280000 / 944238
# [t-SNE] Computed conditional probabilities for sample 281000 / 944238
# [t-SNE] Computed conditional probabilities for sample 282000 / 944238
# [t-SNE] Computed conditional probabilities for sample 283000 / 944238
# [t-SNE] Computed conditional probabilities for sample 284000 / 944238
# [t-SNE] Computed conditional probabilities for sample 285000 / 944238
# [t-SNE] Computed conditional probabilities for sample 286000 / 944238
# [t-SNE] Computed conditional probabilities for sample 287000 / 944238
# [t-SNE] Computed conditional probabilities for sample 288000 / 944238
# [t-SNE] Computed conditional probabilities for sample 289000 / 944238
# [t-SNE] Computed conditional probabilities for sample 290000 / 944238
# [t-SNE] Computed conditional probabilities for sample 291000 / 944238
# [t-SNE] Computed conditional probabilities for sample 292000 / 944238
# [t-SNE] Computed conditional probabilities for sample 293000 / 944238
# [t-SNE] Computed conditional probabilities for sample 294000 / 944238
# [t-SNE] Computed conditional probabilities for sample 295000 / 944238
# [t-SNE] Computed conditional probabilities for sample 296000 / 944238
# [t-SNE] Computed conditional probabilities for sample 297000 / 944238
# [t-SNE] Computed conditional probabilities for sample 298000 / 944238
# [t-SNE] Computed conditional probabilities for sample 299000 / 944238
# [t-SNE] Computed conditional probabilities for sample 300000 / 944238
# [t-SNE] Computed conditional probabilities for sample 301000 / 944238
# [t-SNE] Computed conditional probabilities for sample 302000 / 944238
# [t-SNE] Computed conditional probabilities for sample 303000 / 944238
# [t-SNE] Computed conditional probabilities for sample 304000 / 944238
# [t-SNE] Computed conditional probabilities for sample 305000 / 944238
# [t-SNE] Computed conditional probabilities for sample 306000 / 944238
# [t-SNE] Computed conditional probabilities for sample 307000 / 944238
# [t-SNE] Computed conditional probabilities for sample 308000 / 944238
# [t-SNE] Computed conditional probabilities for sample 309000 / 944238
# [t-SNE] Computed conditional probabilities for sample 310000 / 944238
# [t-SNE] Computed conditional probabilities for sample 311000 / 944238
# [t-SNE] Computed conditional probabilities for sample 312000 / 944238
# [t-SNE] Computed conditional probabilities for sample 313000 / 944238
# [t-SNE] Computed conditional probabilities for sample 314000 / 944238
# [t-SNE] Computed conditional probabilities for sample 315000 / 944238
# [t-SNE] Computed conditional probabilities for sample 316000 / 944238
# [t-SNE] Computed conditional probabilities for sample 317000 / 944238
# [t-SNE] Computed conditional probabilities for sample 318000 / 944238
# [t-SNE] Computed conditional probabilities for sample 319000 / 944238
# [t-SNE] Computed conditional probabilities for sample 320000 / 944238
# [t-SNE] Computed conditional probabilities for sample 321000 / 944238
# [t-SNE] Computed conditional probabilities for sample 322000 / 944238
# [t-SNE] Computed conditional probabilities for sample 323000 / 944238
# [t-SNE] Computed conditional probabilities for sample 324000 / 944238
# [t-SNE] Computed conditional probabilities for sample 325000 / 944238
# [t-SNE] Computed conditional probabilities for sample 326000 / 944238
# [t-SNE] Computed conditional probabilities for sample 327000 / 944238
# [t-SNE] Computed conditional probabilities for sample 328000 / 944238
# [t-SNE] Computed conditional probabilities for sample 329000 / 944238
# [t-SNE] Computed conditional probabilities for sample 330000 / 944238
# [t-SNE] Computed conditional probabilities for sample 331000 / 944238
# [t-SNE] Computed conditional probabilities for sample 332000 / 944238
# [t-SNE] Computed conditional probabilities for sample 333000 / 944238
# [t-SNE] Computed conditional probabilities for sample 334000 / 944238
# [t-SNE] Computed conditional probabilities for sample 335000 / 944238
# [t-SNE] Computed conditional probabilities for sample 336000 / 944238
# [t-SNE] Computed conditional probabilities for sample 337000 / 944238
# [t-SNE] Computed conditional probabilities for sample 338000 / 944238
# [t-SNE] Computed conditional probabilities for sample 339000 / 944238
# [t-SNE] Computed conditional probabilities for sample 340000 / 944238
# [t-SNE] Computed conditional probabilities for sample 341000 / 944238
# [t-SNE] Computed conditional probabilities for sample 342000 / 944238
# [t-SNE] Computed conditional probabilities for sample 343000 / 944238
# [t-SNE] Computed conditional probabilities for sample 344000 / 944238
# [t-SNE] Computed conditional probabilities for sample 345000 / 944238
# [t-SNE] Computed conditional probabilities for sample 346000 / 944238
# [t-SNE] Computed conditional probabilities for sample 347000 / 944238
# [t-SNE] Computed conditional probabilities for sample 348000 / 944238
# [t-SNE] Computed conditional probabilities for sample 349000 / 944238
# [t-SNE] Computed conditional probabilities for sample 350000 / 944238
# [t-SNE] Computed conditional probabilities for sample 351000 / 944238
# [t-SNE] Computed conditional probabilities for sample 352000 / 944238
# [t-SNE] Computed conditional probabilities for sample 353000 / 944238
# [t-SNE] Computed conditional probabilities for sample 354000 / 944238
# [t-SNE] Computed conditional probabilities for sample 355000 / 944238
# [t-SNE] Computed conditional probabilities for sample 356000 / 944238
# [t-SNE] Computed conditional probabilities for sample 357000 / 944238
# [t-SNE] Computed conditional probabilities for sample 358000 / 944238
# [t-SNE] Computed conditional probabilities for sample 359000 / 944238
# [t-SNE] Computed conditional probabilities for sample 360000 / 944238
# [t-SNE] Computed conditional probabilities for sample 361000 / 944238
# [t-SNE] Computed conditional probabilities for sample 362000 / 944238
# [t-SNE] Computed conditional probabilities for sample 363000 / 944238
# [t-SNE] Computed conditional probabilities for sample 364000 / 944238
# [t-SNE] Computed conditional probabilities for sample 365000 / 944238
# [t-SNE] Computed conditional probabilities for sample 366000 / 944238
# [t-SNE] Computed conditional probabilities for sample 367000 / 944238
# [t-SNE] Computed conditional probabilities for sample 368000 / 944238
# [t-SNE] Computed conditional probabilities for sample 369000 / 944238
# [t-SNE] Computed conditional probabilities for sample 370000 / 944238
# [t-SNE] Computed conditional probabilities for sample 371000 / 944238
# [t-SNE] Computed conditional probabilities for sample 372000 / 944238
# [t-SNE] Computed conditional probabilities for sample 373000 / 944238
# [t-SNE] Computed conditional probabilities for sample 374000 / 944238
# [t-SNE] Computed conditional probabilities for sample 375000 / 944238
# [t-SNE] Computed conditional probabilities for sample 376000 / 944238
# [t-SNE] Computed conditional probabilities for sample 377000 / 944238
# [t-SNE] Computed conditional probabilities for sample 378000 / 944238
# [t-SNE] Computed conditional probabilities for sample 379000 / 944238
# [t-SNE] Computed conditional probabilities for sample 380000 / 944238
# [t-SNE] Computed conditional probabilities for sample 381000 / 944238
# [t-SNE] Computed conditional probabilities for sample 382000 / 944238
# [t-SNE] Computed conditional probabilities for sample 383000 / 944238
# [t-SNE] Computed conditional probabilities for sample 384000 / 944238
# [t-SNE] Computed conditional probabilities for sample 385000 / 944238
# [t-SNE] Computed conditional probabilities for sample 386000 / 944238
# [t-SNE] Computed conditional probabilities for sample 387000 / 944238
# [t-SNE] Computed conditional probabilities for sample 388000 / 944238
# [t-SNE] Computed conditional probabilities for sample 389000 / 944238
# [t-SNE] Computed conditional probabilities for sample 390000 / 944238
# [t-SNE] Computed conditional probabilities for sample 391000 / 944238
# [t-SNE] Computed conditional probabilities for sample 392000 / 944238
# [t-SNE] Computed conditional probabilities for sample 393000 / 944238
# [t-SNE] Computed conditional probabilities for sample 394000 / 944238
# [t-SNE] Computed conditional probabilities for sample 395000 / 944238
# [t-SNE] Computed conditional probabilities for sample 396000 / 944238
# [t-SNE] Computed conditional probabilities for sample 397000 / 944238
# [t-SNE] Computed conditional probabilities for sample 398000 / 944238
# [t-SNE] Computed conditional probabilities for sample 399000 / 944238
# [t-SNE] Computed conditional probabilities for sample 400000 / 944238
# [t-SNE] Computed conditional probabilities for sample 401000 / 944238
# [t-SNE] Computed conditional probabilities for sample 402000 / 944238
# [t-SNE] Computed conditional probabilities for sample 403000 / 944238
# [t-SNE] Computed conditional probabilities for sample 404000 / 944238
# [t-SNE] Computed conditional probabilities for sample 405000 / 944238
# [t-SNE] Computed conditional probabilities for sample 406000 / 944238
# [t-SNE] Computed conditional probabilities for sample 407000 / 944238
# [t-SNE] Computed conditional probabilities for sample 408000 / 944238
# [t-SNE] Computed conditional probabilities for sample 409000 / 944238
# [t-SNE] Computed conditional probabilities for sample 410000 / 944238
# [t-SNE] Computed conditional probabilities for sample 411000 / 944238
# [t-SNE] Computed conditional probabilities for sample 412000 / 944238
# [t-SNE] Computed conditional probabilities for sample 413000 / 944238
# [t-SNE] Computed conditional probabilities for sample 414000 / 944238
# [t-SNE] Computed conditional probabilities for sample 415000 / 944238
# [t-SNE] Computed conditional probabilities for sample 416000 / 944238
# [t-SNE] Computed conditional probabilities for sample 417000 / 944238
# [t-SNE] Computed conditional probabilities for sample 418000 / 944238
# [t-SNE] Computed conditional probabilities for sample 419000 / 944238
# [t-SNE] Computed conditional probabilities for sample 420000 / 944238
# [t-SNE] Computed conditional probabilities for sample 421000 / 944238
# [t-SNE] Computed conditional probabilities for sample 422000 / 944238
# [t-SNE] Computed conditional probabilities for sample 423000 / 944238
# [t-SNE] Computed conditional probabilities for sample 424000 / 944238
# [t-SNE] Computed conditional probabilities for sample 425000 / 944238
# [t-SNE] Computed conditional probabilities for sample 426000 / 944238
# [t-SNE] Computed conditional probabilities for sample 427000 / 944238
# [t-SNE] Computed conditional probabilities for sample 428000 / 944238
# [t-SNE] Computed conditional probabilities for sample 429000 / 944238
# [t-SNE] Computed conditional probabilities for sample 430000 / 944238
# [t-SNE] Computed conditional probabilities for sample 431000 / 944238
# [t-SNE] Computed conditional probabilities for sample 432000 / 944238
# [t-SNE] Computed conditional probabilities for sample 433000 / 944238
# [t-SNE] Computed conditional probabilities for sample 434000 / 944238
# [t-SNE] Computed conditional probabilities for sample 435000 / 944238
# [t-SNE] Computed conditional probabilities for sample 436000 / 944238
# [t-SNE] Computed conditional probabilities for sample 437000 / 944238
# [t-SNE] Computed conditional probabilities for sample 438000 / 944238
# [t-SNE] Computed conditional probabilities for sample 439000 / 944238
# [t-SNE] Computed conditional probabilities for sample 440000 / 944238
# [t-SNE] Computed conditional probabilities for sample 441000 / 944238
# [t-SNE] Computed conditional probabilities for sample 442000 / 944238
# [t-SNE] Computed conditional probabilities for sample 443000 / 944238
# [t-SNE] Computed conditional probabilities for sample 444000 / 944238
# [t-SNE] Computed conditional probabilities for sample 445000 / 944238
# [t-SNE] Computed conditional probabilities for sample 446000 / 944238
# [t-SNE] Computed conditional probabilities for sample 447000 / 944238
# [t-SNE] Computed conditional probabilities for sample 448000 / 944238
# [t-SNE] Computed conditional probabilities for sample 449000 / 944238
# [t-SNE] Computed conditional probabilities for sample 450000 / 944238
# [t-SNE] Computed conditional probabilities for sample 451000 / 944238
# [t-SNE] Computed conditional probabilities for sample 452000 / 944238
# [t-SNE] Computed conditional probabilities for sample 453000 / 944238
# [t-SNE] Computed conditional probabilities for sample 454000 / 944238
# [t-SNE] Computed conditional probabilities for sample 455000 / 944238
# [t-SNE] Computed conditional probabilities for sample 456000 / 944238
# [t-SNE] Computed conditional probabilities for sample 457000 / 944238
# [t-SNE] Computed conditional probabilities for sample 458000 / 944238
# [t-SNE] Computed conditional probabilities for sample 459000 / 944238
# [t-SNE] Computed conditional probabilities for sample 460000 / 944238
# [t-SNE] Computed conditional probabilities for sample 461000 / 944238
# [t-SNE] Computed conditional probabilities for sample 462000 / 944238
# [t-SNE] Computed conditional probabilities for sample 463000 / 944238
# [t-SNE] Computed conditional probabilities for sample 464000 / 944238
# [t-SNE] Computed conditional probabilities for sample 465000 / 944238
# [t-SNE] Computed conditional probabilities for sample 466000 / 944238
# [t-SNE] Computed conditional probabilities for sample 467000 / 944238
# [t-SNE] Computed conditional probabilities for sample 468000 / 944238
# [t-SNE] Computed conditional probabilities for sample 469000 / 944238
# [t-SNE] Computed conditional probabilities for sample 470000 / 944238
# [t-SNE] Computed conditional probabilities for sample 471000 / 944238
# [t-SNE] Computed conditional probabilities for sample 472000 / 944238
# [t-SNE] Computed conditional probabilities for sample 473000 / 944238
# [t-SNE] Computed conditional probabilities for sample 474000 / 944238
# [t-SNE] Computed conditional probabilities for sample 475000 / 944238
# [t-SNE] Computed conditional probabilities for sample 476000 / 944238
# [t-SNE] Computed conditional probabilities for sample 477000 / 944238
# [t-SNE] Computed conditional probabilities for sample 478000 / 944238
# [t-SNE] Computed conditional probabilities for sample 479000 / 944238
# [t-SNE] Computed conditional probabilities for sample 480000 / 944238
# [t-SNE] Computed conditional probabilities for sample 481000 / 944238
# [t-SNE] Computed conditional probabilities for sample 482000 / 944238
# [t-SNE] Computed conditional probabilities for sample 483000 / 944238
# [t-SNE] Computed conditional probabilities for sample 484000 / 944238
# [t-SNE] Computed conditional probabilities for sample 485000 / 944238
# [t-SNE] Computed conditional probabilities for sample 486000 / 944238
# [t-SNE] Computed conditional probabilities for sample 487000 / 944238
# [t-SNE] Computed conditional probabilities for sample 488000 / 944238
# [t-SNE] Computed conditional probabilities for sample 489000 / 944238
# [t-SNE] Computed conditional probabilities for sample 490000 / 944238
# [t-SNE] Computed conditional probabilities for sample 491000 / 944238
# [t-SNE] Computed conditional probabilities for sample 492000 / 944238
# [t-SNE] Computed conditional probabilities for sample 493000 / 944238
# [t-SNE] Computed conditional probabilities for sample 494000 / 944238
# [t-SNE] Computed conditional probabilities for sample 495000 / 944238
# [t-SNE] Computed conditional probabilities for sample 496000 / 944238
# [t-SNE] Computed conditional probabilities for sample 497000 / 944238
# [t-SNE] Computed conditional probabilities for sample 498000 / 944238
# [t-SNE] Computed conditional probabilities for sample 499000 / 944238
# [t-SNE] Computed conditional probabilities for sample 500000 / 944238
# [t-SNE] Computed conditional probabilities for sample 501000 / 944238
# [t-SNE] Computed conditional probabilities for sample 502000 / 944238
# [t-SNE] Computed conditional probabilities for sample 503000 / 944238
# [t-SNE] Computed conditional probabilities for sample 504000 / 944238
# [t-SNE] Computed conditional probabilities for sample 505000 / 944238
# [t-SNE] Computed conditional probabilities for sample 506000 / 944238
# [t-SNE] Computed conditional probabilities for sample 507000 / 944238
# [t-SNE] Computed conditional probabilities for sample 508000 / 944238
# [t-SNE] Computed conditional probabilities for sample 509000 / 944238
# [t-SNE] Computed conditional probabilities for sample 510000 / 944238
# [t-SNE] Computed conditional probabilities for sample 511000 / 944238
# [t-SNE] Computed conditional probabilities for sample 512000 / 944238
# [t-SNE] Computed conditional probabilities for sample 513000 / 944238
# [t-SNE] Computed conditional probabilities for sample 514000 / 944238
# [t-SNE] Computed conditional probabilities for sample 515000 / 944238
# [t-SNE] Computed conditional probabilities for sample 516000 / 944238
# [t-SNE] Computed conditional probabilities for sample 517000 / 944238
# [t-SNE] Computed conditional probabilities for sample 518000 / 944238
# [t-SNE] Computed conditional probabilities for sample 519000 / 944238
# [t-SNE] Computed conditional probabilities for sample 520000 / 944238
# [t-SNE] Computed conditional probabilities for sample 521000 / 944238
# [t-SNE] Computed conditional probabilities for sample 522000 / 944238
# [t-SNE] Computed conditional probabilities for sample 523000 / 944238
# [t-SNE] Computed conditional probabilities for sample 524000 / 944238
# [t-SNE] Computed conditional probabilities for sample 525000 / 944238
# [t-SNE] Computed conditional probabilities for sample 526000 / 944238
# [t-SNE] Computed conditional probabilities for sample 527000 / 944238
# [t-SNE] Computed conditional probabilities for sample 528000 / 944238
# [t-SNE] Computed conditional probabilities for sample 529000 / 944238
# [t-SNE] Computed conditional probabilities for sample 530000 / 944238
# [t-SNE] Computed conditional probabilities for sample 531000 / 944238
# [t-SNE] Computed conditional probabilities for sample 532000 / 944238
# [t-SNE] Computed conditional probabilities for sample 533000 / 944238
# [t-SNE] Computed conditional probabilities for sample 534000 / 944238
# [t-SNE] Computed conditional probabilities for sample 535000 / 944238
# [t-SNE] Computed conditional probabilities for sample 536000 / 944238
# [t-SNE] Computed conditional probabilities for sample 537000 / 944238
# [t-SNE] Computed conditional probabilities for sample 538000 / 944238
# [t-SNE] Computed conditional probabilities for sample 539000 / 944238
# [t-SNE] Computed conditional probabilities for sample 540000 / 944238
# [t-SNE] Computed conditional probabilities for sample 541000 / 944238
# [t-SNE] Computed conditional probabilities for sample 542000 / 944238
# [t-SNE] Computed conditional probabilities for sample 543000 / 944238
# [t-SNE] Computed conditional probabilities for sample 544000 / 944238
# [t-SNE] Computed conditional probabilities for sample 545000 / 944238
# [t-SNE] Computed conditional probabilities for sample 546000 / 944238
# [t-SNE] Computed conditional probabilities for sample 547000 / 944238
# [t-SNE] Computed conditional probabilities for sample 548000 / 944238
# [t-SNE] Computed conditional probabilities for sample 549000 / 944238
# [t-SNE] Computed conditional probabilities for sample 550000 / 944238
# [t-SNE] Computed conditional probabilities for sample 551000 / 944238
# [t-SNE] Computed conditional probabilities for sample 552000 / 944238
# [t-SNE] Computed conditional probabilities for sample 553000 / 944238
# [t-SNE] Computed conditional probabilities for sample 554000 / 944238
# [t-SNE] Computed conditional probabilities for sample 555000 / 944238
# [t-SNE] Computed conditional probabilities for sample 556000 / 944238
# [t-SNE] Computed conditional probabilities for sample 557000 / 944238
# [t-SNE] Computed conditional probabilities for sample 558000 / 944238
# [t-SNE] Computed conditional probabilities for sample 559000 / 944238
# [t-SNE] Computed conditional probabilities for sample 560000 / 944238
# [t-SNE] Computed conditional probabilities for sample 561000 / 944238
# [t-SNE] Computed conditional probabilities for sample 562000 / 944238
# [t-SNE] Computed conditional probabilities for sample 563000 / 944238
# [t-SNE] Computed conditional probabilities for sample 564000 / 944238
# [t-SNE] Computed conditional probabilities for sample 565000 / 944238
# [t-SNE] Computed conditional probabilities for sample 566000 / 944238
# [t-SNE] Computed conditional probabilities for sample 567000 / 944238
# [t-SNE] Computed conditional probabilities for sample 568000 / 944238
# [t-SNE] Computed conditional probabilities for sample 569000 / 944238
# [t-SNE] Computed conditional probabilities for sample 570000 / 944238
# [t-SNE] Computed conditional probabilities for sample 571000 / 944238
# [t-SNE] Computed conditional probabilities for sample 572000 / 944238
# [t-SNE] Computed conditional probabilities for sample 573000 / 944238
# [t-SNE] Computed conditional probabilities for sample 574000 / 944238
# [t-SNE] Computed conditional probabilities for sample 575000 / 944238
# [t-SNE] Computed conditional probabilities for sample 576000 / 944238
# [t-SNE] Computed conditional probabilities for sample 577000 / 944238
# [t-SNE] Computed conditional probabilities for sample 578000 / 944238
# [t-SNE] Computed conditional probabilities for sample 579000 / 944238
# [t-SNE] Computed conditional probabilities for sample 580000 / 944238
# [t-SNE] Computed conditional probabilities for sample 581000 / 944238
# [t-SNE] Computed conditional probabilities for sample 582000 / 944238
# [t-SNE] Computed conditional probabilities for sample 583000 / 944238
# [t-SNE] Computed conditional probabilities for sample 584000 / 944238
# [t-SNE] Computed conditional probabilities for sample 585000 / 944238
# [t-SNE] Computed conditional probabilities for sample 586000 / 944238
# [t-SNE] Computed conditional probabilities for sample 587000 / 944238
# [t-SNE] Computed conditional probabilities for sample 588000 / 944238
# [t-SNE] Computed conditional probabilities for sample 589000 / 944238
# [t-SNE] Computed conditional probabilities for sample 590000 / 944238
# [t-SNE] Computed conditional probabilities for sample 591000 / 944238
# [t-SNE] Computed conditional probabilities for sample 592000 / 944238
# [t-SNE] Computed conditional probabilities for sample 593000 / 944238
# [t-SNE] Computed conditional probabilities for sample 594000 / 944238
# [t-SNE] Computed conditional probabilities for sample 595000 / 944238
# [t-SNE] Computed conditional probabilities for sample 596000 / 944238
# [t-SNE] Computed conditional probabilities for sample 597000 / 944238
# [t-SNE] Computed conditional probabilities for sample 598000 / 944238
# [t-SNE] Computed conditional probabilities for sample 599000 / 944238
# [t-SNE] Computed conditional probabilities for sample 600000 / 944238
# [t-SNE] Computed conditional probabilities for sample 601000 / 944238
# [t-SNE] Computed conditional probabilities for sample 602000 / 944238
# [t-SNE] Computed conditional probabilities for sample 603000 / 944238
# [t-SNE] Computed conditional probabilities for sample 604000 / 944238
# [t-SNE] Computed conditional probabilities for sample 605000 / 944238
# [t-SNE] Computed conditional probabilities for sample 606000 / 944238
# [t-SNE] Computed conditional probabilities for sample 607000 / 944238
# [t-SNE] Computed conditional probabilities for sample 608000 / 944238
# [t-SNE] Computed conditional probabilities for sample 609000 / 944238
# [t-SNE] Computed conditional probabilities for sample 610000 / 944238
# [t-SNE] Computed conditional probabilities for sample 611000 / 944238
# [t-SNE] Computed conditional probabilities for sample 612000 / 944238
# [t-SNE] Computed conditional probabilities for sample 613000 / 944238
# [t-SNE] Computed conditional probabilities for sample 614000 / 944238
# [t-SNE] Computed conditional probabilities for sample 615000 / 944238
# [t-SNE] Computed conditional probabilities for sample 616000 / 944238
# [t-SNE] Computed conditional probabilities for sample 617000 / 944238
# [t-SNE] Computed conditional probabilities for sample 618000 / 944238
# [t-SNE] Computed conditional probabilities for sample 619000 / 944238
# [t-SNE] Computed conditional probabilities for sample 620000 / 944238
# [t-SNE] Computed conditional probabilities for sample 621000 / 944238
# [t-SNE] Computed conditional probabilities for sample 622000 / 944238
# [t-SNE] Computed conditional probabilities for sample 623000 / 944238
# [t-SNE] Computed conditional probabilities for sample 624000 / 944238
# [t-SNE] Computed conditional probabilities for sample 625000 / 944238
# [t-SNE] Computed conditional probabilities for sample 626000 / 944238
# [t-SNE] Computed conditional probabilities for sample 627000 / 944238
# [t-SNE] Computed conditional probabilities for sample 628000 / 944238
# [t-SNE] Computed conditional probabilities for sample 629000 / 944238
# [t-SNE] Computed conditional probabilities for sample 630000 / 944238
# [t-SNE] Computed conditional probabilities for sample 631000 / 944238
# [t-SNE] Computed conditional probabilities for sample 632000 / 944238
# [t-SNE] Computed conditional probabilities for sample 633000 / 944238
# [t-SNE] Computed conditional probabilities for sample 634000 / 944238
# [t-SNE] Computed conditional probabilities for sample 635000 / 944238
# [t-SNE] Computed conditional probabilities for sample 636000 / 944238
# [t-SNE] Computed conditional probabilities for sample 637000 / 944238
# [t-SNE] Computed conditional probabilities for sample 638000 / 944238
# [t-SNE] Computed conditional probabilities for sample 639000 / 944238
# [t-SNE] Computed conditional probabilities for sample 640000 / 944238
# [t-SNE] Computed conditional probabilities for sample 641000 / 944238
# [t-SNE] Computed conditional probabilities for sample 642000 / 944238
# [t-SNE] Computed conditional probabilities for sample 643000 / 944238
# [t-SNE] Computed conditional probabilities for sample 644000 / 944238
# [t-SNE] Computed conditional probabilities for sample 645000 / 944238
# [t-SNE] Computed conditional probabilities for sample 646000 / 944238
# [t-SNE] Computed conditional probabilities for sample 647000 / 944238
# [t-SNE] Computed conditional probabilities for sample 648000 / 944238
# [t-SNE] Computed conditional probabilities for sample 649000 / 944238
# [t-SNE] Computed conditional probabilities for sample 650000 / 944238
# [t-SNE] Computed conditional probabilities for sample 651000 / 944238
# [t-SNE] Computed conditional probabilities for sample 652000 / 944238
# [t-SNE] Computed conditional probabilities for sample 653000 / 944238
# [t-SNE] Computed conditional probabilities for sample 654000 / 944238
# [t-SNE] Computed conditional probabilities for sample 655000 / 944238
# [t-SNE] Computed conditional probabilities for sample 656000 / 944238
# [t-SNE] Computed conditional probabilities for sample 657000 / 944238
# [t-SNE] Computed conditional probabilities for sample 658000 / 944238
# [t-SNE] Computed conditional probabilities for sample 659000 / 944238
# [t-SNE] Computed conditional probabilities for sample 660000 / 944238
# [t-SNE] Computed conditional probabilities for sample 661000 / 944238
# [t-SNE] Computed conditional probabilities for sample 662000 / 944238
# [t-SNE] Computed conditional probabilities for sample 663000 / 944238
# [t-SNE] Computed conditional probabilities for sample 664000 / 944238
# [t-SNE] Computed conditional probabilities for sample 665000 / 944238
# [t-SNE] Computed conditional probabilities for sample 666000 / 944238
# [t-SNE] Computed conditional probabilities for sample 667000 / 944238
# [t-SNE] Computed conditional probabilities for sample 668000 / 944238
# [t-SNE] Computed conditional probabilities for sample 669000 / 944238
# [t-SNE] Computed conditional probabilities for sample 670000 / 944238
# [t-SNE] Computed conditional probabilities for sample 671000 / 944238
# [t-SNE] Computed conditional probabilities for sample 672000 / 944238
# [t-SNE] Computed conditional probabilities for sample 673000 / 944238
# [t-SNE] Computed conditional probabilities for sample 674000 / 944238
# [t-SNE] Computed conditional probabilities for sample 675000 / 944238
# [t-SNE] Computed conditional probabilities for sample 676000 / 944238
# [t-SNE] Computed conditional probabilities for sample 677000 / 944238
# [t-SNE] Computed conditional probabilities for sample 678000 / 944238
# [t-SNE] Computed conditional probabilities for sample 679000 / 944238
# [t-SNE] Computed conditional probabilities for sample 680000 / 944238
# [t-SNE] Computed conditional probabilities for sample 681000 / 944238
# [t-SNE] Computed conditional probabilities for sample 682000 / 944238
# [t-SNE] Computed conditional probabilities for sample 683000 / 944238
# [t-SNE] Computed conditional probabilities for sample 684000 / 944238
# [t-SNE] Computed conditional probabilities for sample 685000 / 944238
# ...
# [t-SNE] Computed conditional probabilities for sample 749000 / 944238
# [t-SNE] Computed conditional probabilities for sample 750000 / 944238
# [t-SNE] Computed conditional probabilities for sample 751000 / 944238
# [t-SNE] Computed conditional probabilities for sample 752000 / 944238
# [t-SNE] Computed conditional probabilities for sample 753000 / 944238
# [t-SNE] Computed conditional probabilities for sample 754000 / 944238
# [t-SNE] Computed conditional probabilities for sample 755000 / 944238
# [t-SNE] Computed conditional probabilities for sample 756000 / 944238
# [t-SNE] Computed conditional probabilities for sample 757000 / 944238
# [t-SNE] Computed conditional probabilities for sample 758000 / 944238
# [t-SNE] Computed conditional probabilities for sample 759000 / 944238
# [t-SNE] Computed conditional probabilities for sample 760000 / 944238
# [t-SNE] Computed conditional probabilities for sample 761000 / 944238
# [t-SNE] Computed conditional probabilities for sample 762000 / 944238
# [t-SNE] Computed conditional probabilities for sample 763000 / 944238
# [t-SNE] Computed conditional probabilities for sample 764000 / 944238
# [t-SNE] Computed conditional probabilities for sample 765000 / 944238
# [t-SNE] Computed conditional probabilities for sample 766000 / 944238
# [t-SNE] Computed conditional probabilities for sample 767000 / 944238
# [t-SNE] Computed conditional probabilities for sample 768000 / 944238
# [t-SNE] Computed conditional probabilities for sample 769000 / 944238
# [t-SNE] Computed conditional probabilities for sample 770000 / 944238
# [t-SNE] Computed conditional probabilities for sample 771000 / 944238
# [t-SNE] Computed conditional probabilities for sample 772000 / 944238
# [t-SNE] Computed conditional probabilities for sample 773000 / 944238
# [t-SNE] Computed conditional probabilities for sample 774000 / 944238
# [t-SNE] Computed conditional probabilities for sample 775000 / 944238
# [t-SNE] Computed conditional probabilities for sample 776000 / 944238
# [t-SNE] Computed conditional probabilities for sample 777000 / 944238
# [t-SNE] Computed conditional probabilities for sample 778000 / 944238
# [t-SNE] Computed conditional probabilities for sample 779000 / 944238
# [t-SNE] Computed conditional probabilities for sample 780000 / 944238
# [t-SNE] Computed conditional probabilities for sample 781000 / 944238
# [t-SNE] Computed conditional probabilities for sample 782000 / 944238
# [t-SNE] Computed conditional probabilities for sample 783000 / 944238
# [t-SNE] Computed conditional probabilities for sample 784000 / 944238
# [t-SNE] Computed conditional probabilities for sample 785000 / 944238
# [t-SNE] Computed conditional probabilities for sample 786000 / 944238
# [t-SNE] Computed conditional probabilities for sample 787000 / 944238
# [t-SNE] Computed conditional probabilities for sample 788000 / 944238
# [t-SNE] Computed conditional probabilities for sample 789000 / 944238
# [t-SNE] Computed conditional probabilities for sample 790000 / 944238
# [t-SNE] Computed conditional probabilities for sample 791000 / 944238
# [t-SNE] Computed conditional probabilities for sample 792000 / 944238
# [t-SNE] Computed conditional probabilities for sample 793000 / 944238
# [t-SNE] Computed conditional probabilities for sample 794000 / 944238
# [t-SNE] Computed conditional probabilities for sample 795000 / 944238
# [t-SNE] Computed conditional probabilities for sample 796000 / 944238
# [t-SNE] Computed conditional probabilities for sample 797000 / 944238
# [t-SNE] Computed conditional probabilities for sample 798000 / 944238
# [t-SNE] Computed conditional probabilities for sample 799000 / 944238
# [t-SNE] Computed conditional probabilities for sample 800000 / 944238
# [t-SNE] Computed conditional probabilities for sample 801000 / 944238
# [t-SNE] Computed conditional probabilities for sample 802000 / 944238
# [t-SNE] Computed conditional probabilities for sample 803000 / 944238
# [t-SNE] Computed conditional probabilities for sample 804000 / 944238
# [t-SNE] Computed conditional probabilities for sample 805000 / 944238
# [t-SNE] Computed conditional probabilities for sample 806000 / 944238
# [t-SNE] Computed conditional probabilities for sample 807000 / 944238
# [t-SNE] Computed conditional probabilities for sample 808000 / 944238
# [t-SNE] Computed conditional probabilities for sample 809000 / 944238
# [t-SNE] Computed conditional probabilities for sample 810000 / 944238
# [t-SNE] Computed conditional probabilities for sample 811000 / 944238
# [t-SNE] Computed conditional probabilities for sample 812000 / 944238
# [t-SNE] Computed conditional probabilities for sample 813000 / 944238
# [t-SNE] Computed conditional probabilities for sample 814000 / 944238
# [t-SNE] Computed conditional probabilities for sample 815000 / 944238
# [t-SNE] Computed conditional probabilities for sample 816000 / 944238
# [t-SNE] Computed conditional probabilities for sample 817000 / 944238
# [t-SNE] Computed conditional probabilities for sample 818000 / 944238
# [t-SNE] Computed conditional probabilities for sample 819000 / 944238
# [t-SNE] Computed conditional probabilities for sample 820000 / 944238
# [t-SNE] Computed conditional probabilities for sample 821000 / 944238
# [t-SNE] Computed conditional probabilities for sample 822000 / 944238
# [t-SNE] Computed conditional probabilities for sample 823000 / 944238
# [t-SNE] Computed conditional probabilities for sample 824000 / 944238
# [t-SNE] Computed conditional probabilities for sample 825000 / 944238
# [t-SNE] Computed conditional probabilities for sample 826000 / 944238
# [t-SNE] Computed conditional probabilities for sample 827000 / 944238
# [t-SNE] Computed conditional probabilities for sample 828000 / 944238
# [t-SNE] Computed conditional probabilities for sample 829000 / 944238
# [t-SNE] Computed conditional probabilities for sample 830000 / 944238
# [t-SNE] Computed conditional probabilities for sample 831000 / 944238
# [t-SNE] Computed conditional probabilities for sample 832000 / 944238
# [t-SNE] Computed conditional probabilities for sample 833000 / 944238
# [t-SNE] Computed conditional probabilities for sample 834000 / 944238
# [t-SNE] Computed conditional probabilities for sample 835000 / 944238
# [t-SNE] Computed conditional probabilities for sample 836000 / 944238
# [t-SNE] Computed conditional probabilities for sample 837000 / 944238
# [t-SNE] Computed conditional probabilities for sample 838000 / 944238
# [t-SNE] Computed conditional probabilities for sample 839000 / 944238
# [t-SNE] Computed conditional probabilities for sample 840000 / 944238
# [t-SNE] Computed conditional probabilities for sample 841000 / 944238
# [t-SNE] Computed conditional probabilities for sample 842000 / 944238
# [t-SNE] Computed conditional probabilities for sample 843000 / 944238
# [t-SNE] Computed conditional probabilities for sample 844000 / 944238
# [t-SNE] Computed conditional probabilities for sample 845000 / 944238
# [t-SNE] Computed conditional probabilities for sample 846000 / 944238
# [t-SNE] Computed conditional probabilities for sample 847000 / 944238
# [t-SNE] Computed conditional probabilities for sample 848000 / 944238
# [t-SNE] Computed conditional probabilities for sample 849000 / 944238
# [t-SNE] Computed conditional probabilities for sample 850000 / 944238
# [t-SNE] Computed conditional probabilities for sample 851000 / 944238
# [t-SNE] Computed conditional probabilities for sample 852000 / 944238
# [t-SNE] Computed conditional probabilities for sample 853000 / 944238
# [t-SNE] Computed conditional probabilities for sample 854000 / 944238
# [t-SNE] Computed conditional probabilities for sample 855000 / 944238
# [t-SNE] Computed conditional probabilities for sample 856000 / 944238
# [t-SNE] Computed conditional probabilities for sample 857000 / 944238
# [t-SNE] Computed conditional probabilities for sample 858000 / 944238
# [t-SNE] Computed conditional probabilities for sample 859000 / 944238
# [t-SNE] Computed conditional probabilities for sample 860000 / 944238
# [t-SNE] Computed conditional probabilities for sample 861000 / 944238
# [t-SNE] Computed conditional probabilities for sample 862000 / 944238
# [t-SNE] Computed conditional probabilities for sample 863000 / 944238
# [t-SNE] Computed conditional probabilities for sample 864000 / 944238
# [t-SNE] Computed conditional probabilities for sample 865000 / 944238
# [t-SNE] Computed conditional probabilities for sample 866000 / 944238
# [t-SNE] Computed conditional probabilities for sample 867000 / 944238
# [t-SNE] Computed conditional probabilities for sample 868000 / 944238
# [t-SNE] Computed conditional probabilities for sample 869000 / 944238
# [t-SNE] Computed conditional probabilities for sample 870000 / 944238
# [t-SNE] Computed conditional probabilities for sample 871000 / 944238
# [t-SNE] Computed conditional probabilities for sample 872000 / 944238
# [t-SNE] Computed conditional probabilities for sample 873000 / 944238
# [t-SNE] Computed conditional probabilities for sample 874000 / 944238
# [t-SNE] Computed conditional probabilities for sample 875000 / 944238
# [t-SNE] Computed conditional probabilities for sample 876000 / 944238
# [t-SNE] Computed conditional probabilities for sample 877000 / 944238
# [t-SNE] Computed conditional probabilities for sample 878000 / 944238
# [t-SNE] Computed conditional probabilities for sample 879000 / 944238
# [t-SNE] Computed conditional probabilities for sample 880000 / 944238
# [t-SNE] Computed conditional probabilities for sample 881000 / 944238
# [t-SNE] Computed conditional probabilities for sample 882000 / 944238
# [t-SNE] Computed conditional probabilities for sample 883000 / 944238
# [t-SNE] Computed conditional probabilities for sample 884000 / 944238
# [t-SNE] Computed conditional probabilities for sample 885000 / 944238
# [t-SNE] Computed conditional probabilities for sample 886000 / 944238
# [t-SNE] Computed conditional probabilities for sample 887000 / 944238
# [t-SNE] Computed conditional probabilities for sample 888000 / 944238
# [t-SNE] Computed conditional probabilities for sample 889000 / 944238
# [t-SNE] Computed conditional probabilities for sample 890000 / 944238
# [t-SNE] Computed conditional probabilities for sample 891000 / 944238
# [t-SNE] Computed conditional probabilities for sample 892000 / 944238
# [t-SNE] Computed conditional probabilities for sample 893000 / 944238
# [t-SNE] Computed conditional probabilities for sample 894000 / 944238
# [t-SNE] Computed conditional probabilities for sample 895000 / 944238
# [t-SNE] Computed conditional probabilities for sample 896000 / 944238
# [t-SNE] Computed conditional probabilities for sample 897000 / 944238
# [t-SNE] Computed conditional probabilities for sample 898000 / 944238
# [t-SNE] Computed conditional probabilities for sample 899000 / 944238
# [t-SNE] Computed conditional probabilities for sample 900000 / 944238
# [t-SNE] Computed conditional probabilities for sample 901000 / 944238
# [t-SNE] Computed conditional probabilities for sample 902000 / 944238
# [t-SNE] Computed conditional probabilities for sample 903000 / 944238
# [t-SNE] Computed conditional probabilities for sample 904000 / 944238
# [t-SNE] Computed conditional probabilities for sample 905000 / 944238
# [t-SNE] Computed conditional probabilities for sample 906000 / 944238
# [t-SNE] Computed conditional probabilities for sample 907000 / 944238
# [t-SNE] Computed conditional probabilities for sample 908000 / 944238
# [t-SNE] Computed conditional probabilities for sample 909000 / 944238
# [t-SNE] Computed conditional probabilities for sample 910000 / 944238
# [t-SNE] Computed conditional probabilities for sample 911000 / 944238
# [t-SNE] Computed conditional probabilities for sample 912000 / 944238
# [t-SNE] Computed conditional probabilities for sample 913000 / 944238
# [t-SNE] Computed conditional probabilities for sample 914000 / 944238
# [t-SNE] Computed conditional probabilities for sample 915000 / 944238
# [t-SNE] Computed conditional probabilities for sample 916000 / 944238
# [t-SNE] Computed conditional probabilities for sample 917000 / 944238
# [t-SNE] Computed conditional probabilities for sample 918000 / 944238
# [t-SNE] Computed conditional probabilities for sample 919000 / 944238
# [t-SNE] Computed conditional probabilities for sample 920000 / 944238
# [t-SNE] Computed conditional probabilities for sample 921000 / 944238
# [t-SNE] Computed conditional probabilities for sample 922000 / 944238
# [t-SNE] Computed conditional probabilities for sample 923000 / 944238
# [t-SNE] Computed conditional probabilities for sample 924000 / 944238
# [t-SNE] Computed conditional probabilities for sample 925000 / 944238
# [t-SNE] Computed conditional probabilities for sample 926000 / 944238
# [t-SNE] Computed conditional probabilities for sample 927000 / 944238
# [t-SNE] Computed conditional probabilities for sample 928000 / 944238
# [t-SNE] Computed conditional probabilities for sample 929000 / 944238
# [t-SNE] Computed conditional probabilities for sample 930000 / 944238
# [t-SNE] Computed conditional probabilities for sample 931000 / 944238
# [t-SNE] Computed conditional probabilities for sample 932000 / 944238
# [t-SNE] Computed conditional probabilities for sample 933000 / 944238
# [t-SNE] Computed conditional probabilities for sample 934000 / 944238
# [t-SNE] Computed conditional probabilities for sample 935000 / 944238
# [t-SNE] Computed conditional probabilities for sample 936000 / 944238
# [t-SNE] Computed conditional probabilities for sample 937000 / 944238
# [t-SNE] Computed conditional probabilities for sample 938000 / 944238
# [t-SNE] Computed conditional probabilities for sample 939000 / 944238
# [t-SNE] Computed conditional probabilities for sample 940000 / 944238
# [t-SNE] Computed conditional probabilities for sample 941000 / 944238
# [t-SNE] Computed conditional probabilities for sample 942000 / 944238
# [t-SNE] Computed conditional probabilities for sample 943000 / 944238
# [t-SNE] Computed conditional probabilities for sample 944000 / 944238
# [t-SNE] Computed conditional probabilities for sample 944238 / 944238
# [t-SNE] Mean sigma: 0.010278
# [t-SNE] Computed conditional probabilities in 78.903s
# [t-SNE] Iteration 50: error = 152.4771423, gradient norm = 0.0000001 (50 iterations in 194.093s)
# [t-SNE] Iteration 100: error = 152.4771576, gradient norm = 0.0000001 (50 iterations in 186.572s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 152.477158
# [t-SNE] Iteration 150: error = 10.2493744, gradient norm = 0.0000003 (50 iterations in 185.234s)
# [t-SNE] Iteration 200: error = 10.2493725, gradient norm = 0.0000039 (50 iterations in 184.867s)
# [t-SNE] Iteration 250: error = 10.2456007, gradient norm = 0.0001775 (50 iterations in 184.433s)
# [t-SNE] Iteration 300: error = 9.3035212, gradient norm = 0.0007427 (50 iterations in 181.120s)
# [t-SNE] Iteration 350: error = 8.5885210, gradient norm = 0.0004333 (50 iterations in 174.160s)
# [t-SNE] Iteration 400: error = 8.2068472, gradient norm = 0.0003278 (50 iterations in 188.415s)
# [t-SNE] Iteration 450: error = 7.9269023, gradient norm = 0.0002734 (50 iterations in 198.518s)
# [t-SNE] Iteration 500: error = 7.6946006, gradient norm = 0.0002389 (50 iterations in 189.477s)
# [t-SNE] Iteration 550: error = 7.4904833, gradient norm = 0.0002138 (50 iterations in 209.327s)
# [t-SNE] Iteration 600: error = 7.3043509, gradient norm = 0.0001937 (50 iterations in 212.574s)
# [t-SNE] Iteration 650: error = 7.1348238, gradient norm = 0.0001769 (50 iterations in 210.914s)
# [t-SNE] Iteration 700: error = 6.9792438, gradient norm = 0.0001626 (50 iterations in 218.945s)
# [t-SNE] Iteration 750: error = 6.8357735, gradient norm = 0.0001504 (50 iterations in 214.530s)
# [t-SNE] Iteration 800: error = 6.7028537, gradient norm = 0.0001397 (50 iterations in 203.750s)
# [t-SNE] Iteration 850: error = 6.5792241, gradient norm = 0.0001303 (50 iterations in 214.393s)
# [t-SNE] Iteration 900: error = 6.4639969, gradient norm = 0.0001219 (50 iterations in 207.308s)
# [t-SNE] Iteration 950: error = 6.3561788, gradient norm = 0.0001145 (50 iterations in 203.948s)
# [t-SNE] Iteration 1000: error = 6.2548614, gradient norm = 0.0001080 (50 iterations in 201.189s)
# [t-SNE] KL divergence after 1000 iterations: 6.254861

# %%
intr_file = '../data/hg19_intr_clean.fa'
depl_file = '../data/hg19_depl_clean.fa'

e = 0
intr_seqs = []
depl_seqs = []
for intr, depl in zip(SeqIO.parse(intr_file, 'fasta'), SeqIO.parse(depl_file, 'fasta')):
    
    #cutoff = 200
    #my_intr_seq = str(intr.seq)[0:cutoff]
    #my_depl_seq = str(depl.seq)[0:cutoff]
    #intr_seqs.append(my_intr_seq)
    #depl_seqs.append(my_depl_seq)
    
    step = 200; jump = 1; a = 0; b = step; n_jumps = 5
    for j in range(n_jumps):
        s_intr = str(intr.seq)[a:b]
        s_depl = str(depl.seq)[a:b]
        intr_seqs.append(s_intr)
        depl_seqs.append(s_depl)
        a = a + jump
        b = a + step
    
    e = e + 1
    if e%20000 == 0:
        print('Finished ' + str(e) + ' entries')
        
def getKmers(sequence, size):
    return [sequence[x:x+size].upper() for x in range(len(sequence) - size + 1)]

kmer = 10
intr_texts = [' '.join(getKmers(i, kmer)) for i in intr_seqs]
depl_texts = [' '.join(getKmers(i, kmer)) for i in depl_seqs]
# Out:
# Finished 20000 entries
# Finished 40000 entries
# Finished 60000 entries

# %%
merge_texts = intr_texts + depl_texts
len(merge_texts)
# Out:
# 733640

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(merge_texts)
#X = tokenizer.texts_to_matrix(merge_texts, mode = 'freq')

encoded_docs = tokenizer.texts_to_sequences(merge_texts)
max_length = max([len(s.split()) for s in merge_texts])
X = pad_sequences(encoded_docs, maxlen = max_length, padding = 'post')

print(X)
print('\n')
print(X.shape)
# Out:
# [[153634 568397 382160 ... 635443 506832 658088]
#  [568397 382160 380712 ... 506832 658088 654350]
#  [382160 380712 323461 ... 658088 654350 503434]
#  ...
#  [  1173    900    397 ...  64841  93299 115195]
#  [   900    397    537 ...  93299 115195 135311]
#  [   397    537   1117 ... 115195 135311  63747]]
#
#
# (733640, 191)

# %%
pred = ["TTTTTTTTTT", "AAAAAAAAAA", "TCCTTCCTTC", "CCTTCCTTCC", "CTTCCTTCCT", "TTCCTTCCTT", "TTTTTTTTTG", 
        "AAGGAAAAAA", "CCTCCCTCCC", "TCTATGCAAA", "CTCTCTCTCT", "TCTCTCTCTT", "CTCTCTCTTC", "CCTTTTAATT",
        "GGCTAATTTT", "TTTAATTTTT", "CTTTTGTTCT", "TTTTGTTCTT", "TAATTTTTTT", "CTCCCTCCCT"]

pred = [i.lower() for i in pred]

print(pred)
# Out:
# ['tttttttttt', 'aaaaaaaaaa', 'tccttccttc', 'ccttccttcc', 'cttccttcct', 'ttccttcctt', 'tttttttttg', 'aaggaaaaaa', 'cctccctccc', 'tctatgcaaa', 'ctctctctct', 'tctctctctt', 'ctctctcttc', 'ccttttaatt', 'ggctaatttt', 'tttaattttt', 'cttttgttct', 'ttttgttctt', 'taattttttt', 'ctccctccct']

# %%
plt.figure(figsize = (15,15))

plt.scatter(emb_tsne[:,0],emb_tsne[:,1], color = 'green')
for i,j in tokenizer.word_index.items():
    if(i in pred):
        plt.annotate(i, (emb_tsne[j,0], emb_tsne[j,1]))
plt.show()

# %%
"""plt.figure(figsize = (15,15))

plt.scatter(emb_pca[:,0],emb_pca[:,1], color = 'green')
for i,j in tokenizer.word_index.items():
    if(i in pred):
        plt.annotate(i, (emb_pca[j,0], emb_pca[j,1]))
plt.show()"""
# Out:
# "plt.figure(figsize = (15,15))\n\nplt.scatter(emb_pca[:,0],emb_pca[:,1], color = 'green')\nfor i,j in tokenizer.word_index.items():\n    if(i in pred):\n        plt.annotate(i, (emb_pca[j,0], emb_pca[j,1]))\nplt.show()"

# %%
"""from sklearn.datasets import load_digits
from sklearn.decomposition import KernelPCA

transformer = KernelPCA(n_components=2, kernel='linear')
X_transformed = transformer.fit_transform(map_model)
X_transformed.shape"""
# Out:
# "from sklearn.datasets import load_digits\nfrom sklearn.decomposition import KernelPCA\n\ntransformer = KernelPCA(n_components=2, kernel='linear')\nX_transformed = transformer.fit_transform(map_model)\nX_transformed.shape"

# %%
"""from sklearn.datasets import load_digits
from sklearn.manifold import Isomap

embedding = Isomap(n_components=2)
X_transformed = embedding.fit_transform(map_model)
X_transformed.shape"""
# Out:
# 'from sklearn.datasets import load_digits\nfrom sklearn.manifold import Isomap\n\nembedding = Isomap(n_components=2)\nX_transformed = embedding.fit_transform(map_model)\nX_transformed.shape'

# %%
"""plt.figure(figsize = (15,15))

plt.scatter(X_transformed[:,0],X_transformed[:,1], color = 'green')
for i,j in tokenizer.word_index.items():
    if(i in pred):
        plt.annotate(i, (X_transformed[j,0], X_transformed[j,1]))
plt.show()"""
# Out:
# "plt.figure(figsize = (15,15))\n\nplt.scatter(X_transformed[:,0],X_transformed[:,1], color = 'green')\nfor i,j in tokenizer.word_index.items():\n    if(i in pred):\n        plt.annotate(i, (X_transformed[j,0], X_transformed[j,1]))\nplt.show()"
